# %%
import random 

again = True

while again:
      print(random.randint(1,8))
      another_roll=input("You wanna swerve the dice? (yes/No)")
      if another_roll.lower()=="yes":
         continue 
      else:
          break
# Out:
# 2
# You wanna swerve the dice? (yes/No)yes
# 4
